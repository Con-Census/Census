# %%
import os
import pandas as pd
import numpy as np
from tabulate import tabulate
from datetime import datetime
from sklearn.impute import SimpleImputer

# %%
with open('transactions.csv', 'r') as f:
        reader = csv.reader(f)
        print(reader)

# %%
reader

# %%
csv.reader

# %%
list(reader)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 list(reader)
#
# ValueError: I/O operation on closed file.

# %%
with open('transactions.csv', 'r') as file:
            reader = csv.reader(file)
            for row in reader:
                balance = (row[-1])
                print(balance)
# Out:
# Balance
# 0
# 300

# %%
with open('transactions.csv', 'r') as file:
    reader = csv.reader(file)
    data = list(reader)
    print(data)
    print('')
    print(data[-1][-1])
# Out:
# [['Date', 'Description', 'Amount', 'Balance'], ['0000-00-00', 'Initial Creation', '0', '0'], ['2022-10-26', 'ATM Deposit', '300', '300']]
#
# 300

# %%
type(data)
# Out:
# list

# %%
from tabula import read_pdf
import pandas as pd

# %%
import math
import numpy as np

# %%
f = read_pdf('CostofFoodSep2022LowModLib.pdf', pages='all')
f
# Out:
# [        Unnamed: 0 Unnamed: 1 Weekly cost 2 Unnamed: 2 Unnamed: 3  \
#  0              NaN   Low-cost     Moderate-    Liberal   Low-cost
#  1   Age-sex groups       plan     cost plan       plan       plan
#  2    Individuals 3        NaN           NaN        NaN        NaN
#  3           Child:        NaN           NaN        NaN        NaN
#  4           1 year     $35.50        $40.30     $48.80    $153.60
#  5        2-3 years     $37.50        $44.90     $54.70    $162.60
#  6        4-5 years     $38.60        $47.80     $57.70    $167.00
#  7        6-8 years     $54.40        $65.50     $76.70    $235.80
#  8       9-11 years     $58.30        $75.40     $87.90    $252.50
#  9            Male:        NaN           NaN        NaN        NaN
#  10     12-13 years     $67.70        $84.20     $98.80    $293.30
#  11     14-18 years     $68.70        $86.60     $99.90    $297.80
#  12     19-50 years     $68.00        $85.30    $103.80    $294.70
# ...

# %%
len([153.60, 162.60, 167.00, 235.80, 252.50, 293.30, 297.80, 294.70, 278.00, 274.40, 251.20, 250.40, 255.40, 247.30])
# Out:
# 14

# %%
d = {'age-sex groups': ['Child: 1', 'Child: 2-3', 'Child: 4-5', 'Child: 6-8', 'Child: 9-11', 'Male: 12-13', 'Male: 14-18', 'Male: 19-50', 'Male: 51-70', 'Male: 71+', 'Female: 12-13', 'Female: 14-18', 'Female: 19-50', 'Female: 51-70', 'Female: 71+'],\
     'low-cost plan': [153.60, 162.60, 167.00, 235.80, 252.50, 293.30, 297.80, 294.70, 278.00, 274.40, 251.20, 250.40, 255.40, 249.50, 247.30],\
     'moderate-cost plan': [174.50, 194.70, 207.10, 284.00, 326.80, 364.90, 375.30, 369.60, 350.10, 339.70, 300.90, 298.60, 312.20, 310.30, 305.60],\
     'liberal plan': [211.60, 236.80, 250.10, 332.50, 380.70, 428.10, 432.90, 449.70, 417.30, 416.60, 371.20, 369.10, 398.70, 372.60, 366.70]}

# %%
food = pd.DataFrame(d)
food
# Out:
#    age-sex groups  low-cost plan  moderate-cost plan  liberal plan
# 0        Child: 1          153.6               174.5         211.6
# 1      Child: 2-3          162.6               194.7         236.8
# 2      Child: 4-5          167.0               207.1         250.1
# 3      Child: 6-8          235.8               284.0         332.5
# 4     Child: 9-11          252.5               326.8         380.7
# 5     Male: 12-13          293.3               364.9         428.1
# 6     Male: 14-18          297.8               375.3         432.9
# 7     Male: 19-50          294.7               369.6         449.7
# 8     Male: 51-70          278.0               350.1         417.3
# 9       Male: 71+          274.4               339.7         416.6
# 10  Female: 12-13          251.2               300.9         371.2
# 11  Female: 14-18          250.4               298.6         369.1
# 12  Female: 19-50          255.4               312.2         398.7
# ...

# %%
#food.to_csv('USDA_food_cost.csv')

# %%
food
# Out:
#    age-sex groups  low-cost plan  moderate-cost plan  liberal plan
# 0        Child: 1          153.6               174.5         211.6
# 1      Child: 2-3          162.6               194.7         236.8
# 2      Child: 4-5          167.0               207.1         250.1
# 3      Child: 6-8          235.8               284.0         332.5
# 4     Child: 9-11          252.5               326.8         380.7
# 5     Male: 12-13          293.3               364.9         428.1
# 6     Male: 14-18          297.8               375.3         432.9
# 7     Male: 19-50          294.7               369.6         449.7
# 8     Male: 51-70          278.0               350.1         417.3
# 9       Male: 71+          274.4               339.7         416.6
# 10  Female: 12-13          251.2               300.9         371.2
# 11  Female: 14-18          250.4               298.6         369.1
# 12  Female: 19-50          255.4               312.2         398.7
# ...

# %%
food['moderate-cost plan'].mean(axis=0)
# Out:
# 300.9533333333333

# %%
t = read_pdf('CostofFoodSep2022Thrifty.pdf', pages='all')
t
# Out:
# [                                       Age-sex group  \
#  0  Individuals3\rChild:\r1 year\r2-3 years\r4-5 y...
#  1  Reference Family:4\rMale and Female, 20-50 yea...
#
#                                          Weekly cost2  \
#  0  $25.00\r$37.70\r$40.90\r$45.60\r$52.70\r\r$56....
#  1                                            $222.80
#
#                                         Monthly cost2
#  0  $108.20\r$163.20\r$177.20\r$197.70\r$228.50\r\...
#  1                                            $965.30  ]

# %%
t[1:3]
# Out:
# []

# %%
a = read_pdf('0309_counties.pdf', pages='all')
a
# Out:
# [                 Unnamed: 0 Unnamed: 1 Unnamed: 2    Total Program Unnamed: 3  \
#  0                       NaN     County        NaN              NaN       Rank
#  1                       NaN        NaN        NaN     Expenditures        NaN
#  2             United States        NaN          $  446,662,221,261        NaN
#  3            Ada County, ID        NaN          $      426,823,240        131
#  4          Adams County, CO        NaN          $      212,664,763        176
#  5        Alameda County, CA        NaN          $    3,497,503,509         10
#  6      Allegheny County, PA        NaN          $    1,885,978,583         32
#  7          Allen County, IN        NaN          $      283,564,823        159
#  8   Anne Arundel County, MD        NaN          $      360,399,116        146
#  9          Anoka County, MN        NaN          $      113,338,099        193
#  10      Arapahoe County, CO        NaN          $      428,989,921        130
# ...

# %% [markdown]
# ---

# %% [markdown]
# Population:	142,874
# FEMA Risk Index Score:	10.56
# FEMA Annual Expected Loss Score:	13.8
# Overall Score Rating:	Mini
# https://housegrail.com/safest-cities-from-natural-disasters-in-the-us/

# %% [markdown]
# columns={'Population', FEMA Risk Index Score','Annual Expected Loss Score','Overall Score Rating'}

# %%
c = pd.DataFrame(np.array([['Syracuse, NY', 'Leesburg, VA', 'Cleveland, OH', 'Corvallis, OR', 'Grand Junction, CO', 'Akron, OH', 'Dayton, OH', 'Allentown, PA', 'Spokane, WA', 'Bozeman, MT', 'Montpelier, VT', 'Tooele, UT', 'Wrangell, AK', 'Cusseta, GA', 'Marmarth, ND'],\
[142874, 52994, 385282, 58028, 62062, 198051, 140569, 120915, 217353, 46746, 7477, 34535, 2500, 10560, 143],\
[10.56, 12.08, 6.03, 11.41, 12.95, 17.54, 17.93, 13.16, 17.26, 5.91, 9.31, 5.65, 2.23, 12.63, 0.68],\
[13.8, 14.54, 12.31, 20.10, 14.83, 18.48, 20.17, 11.88, 16.28, 14.88, 10.41, 15.19, 1.74, 12.39, 4.83],\
['Mini', 'Very low', 'Very low', 'Moderately low', 'Relatively low', 'Relatively low', 'Relatively low', 'Very low', 'Relatively low', 'Relatively low', 'Very low', 'Very low', 'Very low', 'Very low', 'Very low']]), columns=['city', 'Population', 'FEMA Risk Index Score', 'FEMA Annual Expected Loss Score', 'Overall Score Rating'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [73], in <cell line: 1>()
# ----> 1 c = pd.DataFrame(np.array([['Syracuse, NY', 'Leesburg, VA', 'Cleveland, OH', 'Corvallis, OR', 'Grand Junction, CO', 'Akron, OH', 'Dayton, OH', 'Allentown, PA', 'Spokane, WA', 'Bozeman, MT', 'Montpelier, VT', 'Tooele, UT', 'Wrangell, AK', 'Cusseta, GA', 'Marmarth, ND'],\
#       2 [142874, 52994, 385282, 58028, 62062, 198051, 140569, 120915, 217353, 46746, 7477, 34535, 2500, 10560, 143],\
#       3 [10.56, 12.08, 6.03, 11.41, 12.95, 17.54, 17.93, 13.16, 17.26, 5.91, 9.31, 5.65, 2.23, 12.63, 0.68],\
#       4 [13.8, 14.54, 12.31, 20.10, 14.83, 18.48, 20.17, 11.88, 16.28, 14.88, 10.41, 15.19, 1.74, 12.39, 4.83],\
# ...

# %%
{'Population': [],\
 'FEMA Risk Index Score':
 'Annual Expected Loss Score':
 'Overall Score Rating':
}

# %%
x = pd.read_csv('pop_per_county.csv')
x
# Out:
# /var/folders/t2/c4rfp_5j33nfsbfkcj7scwjh0000gn/T/ipykernel_25001/11905031.py:1: DtypeWarning: Columns (2,3,70,71,72,73,78,79,80,81,130,131,250,251,254,255,256,257,278,281,282,283,302,303,342,343,344,345,358,361,434,435,436,437,486,489,606,609,610,611,612,613,634,635,638,639,658,661) have mixed types. Specify dtype option on import or set low_memory=False.
#   x = pd.read_csv('pop_per_county.csv')
#                 GEO_ID                               NAME  \
# 0            Geography               Geographic Area Name
# 1       0500000US01003            Baldwin County, Alabama
# 2       0500000US01015            Calhoun County, Alabama
# 3       0500000US01043            Cullman County, Alabama
# 4       0500000US01049             DeKalb County, Alabama
# ...                ...                                ...
# 1472  1600000US7210334    Caguas zona urbana, Puerto Rico
# 1473  1600000US7214290  Carolina zona urbana, Puerto Rico
# ...

# %%
#x.iloc[1:,:3].values

# %%
z = x.iloc[1:,:3]
z
# Out:
#                 GEO_ID                               NAME DP05_0001E
# 1       0500000US01003            Baldwin County, Alabama     239294
# 2       0500000US01015            Calhoun County, Alabama     115972
# 3       0500000US01043            Cullman County, Alabama      89496
# 4       0500000US01049             DeKalb County, Alabama      71813
# 5       0500000US01051             Elmore County, Alabama      89304
# ...                ...                                ...        ...
# 1472  1600000US7210334    Caguas zona urbana, Puerto Rico      76577
# 1473  1600000US7214290  Carolina zona urbana, Puerto Rico     141050
# 1474  1600000US7232522  Guaynabo zona urbana, Puerto Rico      72088
# 1475  1600000US7263820     Ponce zona urbana, Puerto Rico     112005
# 1476  1600000US7276770  San Juan zona urbana, Puerto Rico     320456
#
# [1476 rows x 3 columns]

# %%
z.columns = z.columns.str.lower()

# %%
z.head()
# Out:
#            geo_id                     name dp05_0001e
# 1  0500000US01003  Baldwin County, Alabama     239294
# 2  0500000US01015  Calhoun County, Alabama     115972
# 3  0500000US01043  Cullman County, Alabama      89496
# 4  0500000US01049   DeKalb County, Alabama      71813
# 5  0500000US01051   Elmore County, Alabama      89304

# %%
z.rename(columns={'name':'geographic_area', 'dp05_0001e':'total_population'}, inplace=True)

# %%
#z.to_csv('county_pop.csv')

# %%
z = pd.read_csv('county_pop.csv', index_col=0)
z
# Out:
#                 geo_id                    geographic_area  total_population
# 1       0500000US01003            Baldwin County, Alabama            239294
# 2       0500000US01015            Calhoun County, Alabama            115972
# 3       0500000US01043            Cullman County, Alabama             89496
# 4       0500000US01049             DeKalb County, Alabama             71813
# 5       0500000US01051             Elmore County, Alabama             89304
# ...                ...                                ...               ...
# 1472  1600000US7210334    Caguas zona urbana, Puerto Rico             76577
# 1473  1600000US7214290  Carolina zona urbana, Puerto Rico            141050
# 1474  1600000US7232522  Guaynabo zona urbana, Puerto Rico             72088
# 1475  1600000US7263820     Ponce zona urbana, Puerto Rico            112005
# 1476  1600000US7276770  San Juan zona urbana, Puerto Rico            320456
#
# [1476 rows x 3 columns]

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1476 entries, 1 to 1476
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   geo_id            1476 non-null   object
#  1   geographic_area   1476 non-null   object
#  2   total_population  1476 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 46.1+ KB

# %%
z['monthly_food_cost'] = z.total_population * 301
z
# Out:
#                 geo_id                    geographic_area  total_population  \
# 1       0500000US01003            Baldwin County, Alabama            239294
# 2       0500000US01015            Calhoun County, Alabama            115972
# 3       0500000US01043            Cullman County, Alabama             89496
# 4       0500000US01049             DeKalb County, Alabama             71813
# 5       0500000US01051             Elmore County, Alabama             89304
# ...                ...                                ...               ...
# 1472  1600000US7210334    Caguas zona urbana, Puerto Rico             76577
# 1473  1600000US7214290  Carolina zona urbana, Puerto Rico            141050
# 1474  1600000US7232522  Guaynabo zona urbana, Puerto Rico             72088
# 1475  1600000US7263820     Ponce zona urbana, Puerto Rico            112005
# 1476  1600000US7276770  San Juan zona urbana, Puerto Rico            320456
#
#       monthly_food_cost
# 1              72027494
# ...

# %%
#z.to_csv('county_pop.csv')

# %%
pd.read_csv('state-freq-data.csv')
# Out:
#                                                                           Billion-Dollar Disasters By Year (CPI-Adjusted)
# year state drought flooding freeze severe storm tropical cyclone wildfire                                    winter storm
# 1980 AK    0       0        0      0            0                0                                                      0
#      AL    1       0        0      0            0                0                                                      0
#      AR    1       1        0      0            0                0                                                      0
#      AZ    0       0        0      0            0                0                                                      0
# ...                                                                                                                   ...
# 2022 VT    0       0        0      0            0                0                                                      0
# ...

# %% [markdown]
# https://www.businessinsider.com/us-sustainable-cities-most-likely-to-survive-a-disaster-2017-9#10-portland-vancouver-hillsboro-oregon-washington-1
# The 10 spots in the US that are most prepared for disaster:
#
# 10. Portland-Vancouver-Hillsboro, Oregon-Washington
#     Index score out of 100: 43.93
#
# 9. Boston-Cambridge-Newton, Massachusetts-New Hampshire
#     Index score out of 100: 53.88
#
# 8. Oxnard-Thousand Oaks-Ventura, California
#     Index score out of 100: 53.98
#
# 7. Boise City, Idaho
#     Index score out of 100: 55.23
#
# 6. Albany-Schenectady-Troy, New York
#     Index score out of 100: 56.29
#
# 5. San Diego-Carlsbad, California
#     Index score out of 100: 56.38
#
# 4. San Francisco–Oakland–Hayward, California
#     Index score out of 100: 56.43
#
# 3. Seattle-Tacoma-Bellevue, Washington
#     Index score out of 100: 57.98
#
# 2. Provo-Orem, Utah
#     Index score out of 100: 58.05
#
# 1. San Jose-Sunnyvale-Santa Clara, California
#     Index score out of 100: 61.04

# %%
q = pd.read_csv('Untitled spreadsheet - Sheet1.csv')
q
# Out:
#     Unnamed: 0                     Unnamed: 1       Unnamed: 2  \
# 0          NaN             midyear_population              NaN
# 1          NaN                   country_code           STRING
# 2          NaN                   country_name           STRING
# 3          NaN                           year          INTEGER
# 4          NaN             midyear_population          INTEGER
# ..         ...                            ...              ...
# 74         NaN            American Samoa (AS)     $503,121,573
# 75         NaN                      Guam (GU)   $2,548,619,598
# 76         NaN  Northern Mariana Islands (MP)     $494,228,437
# 77         NaN               Puerto Rico (PR)  $36,929,831,638
# 78         NaN       U.S. Virgin Islands (VI)   $1,776,567,277
#
#                                            Unnamed: 3
# 0                                                 NaN
# 1   Federal Information Processing Standard (FIPS)...
# ...

# %%
k = q.iloc[23:,:].drop(columns={'Unnamed: 0'}).rename(columns={'Unnamed: 1': 'state', 'Unnamed: 2': 'funding', 'Unnamed: 3': '%_of_total'})
k
# Out:
#                             state           funding %_of_total
# 23                   Alabama (AL)   $54,697,779,694      1.33%
# 24                    Alaska (AK)   $13,617,642,444      0.33%
# 25                   Arizona (AZ)   $97,000,340,211      2.36%
# 26                  Arkansas (AR)   $29,378,338,658      0.72%
# 27                California (CA)  $390,811,907,053      9.52%
# 28                  Colorado (CO)   $53,910,424,226      1.31%
# 29               Connecticut (CT)  $104,360,084,694      2.54%
# 30                  Delaware (DE)    $9,905,940,162      0.24%
# 31      District of Columbia (DC)   $48,804,556,621      1.19%
# 32                   Florida (FL)  $239,415,273,788      5.83%
# 33                   Georgia (GA)   $87,940,793,553      2.14%
# 34                    Hawaii (HI)   $15,336,370,543      0.37%
# 35                     Idaho (ID)   $17,000,463,101      0.41%
# 36                  Illinois (IL)  $109,447,513,878      2.67%
# ...

# %%
k = k.reset_index(drop=True)
k
# Out:
#                             state           funding %_of_total
# 0                    Alabama (AL)   $54,697,779,694      1.33%
# 1                     Alaska (AK)   $13,617,642,444      0.33%
# 2                    Arizona (AZ)   $97,000,340,211      2.36%
# 3                   Arkansas (AR)   $29,378,338,658      0.72%
# 4                 California (CA)  $390,811,907,053      9.52%
# 5                   Colorado (CO)   $53,910,424,226      1.31%
# 6                Connecticut (CT)  $104,360,084,694      2.54%
# 7                   Delaware (DE)    $9,905,940,162      0.24%
# 8       District of Columbia (DC)   $48,804,556,621      1.19%
# 9                    Florida (FL)  $239,415,273,788      5.83%
# 10                   Georgia (GA)   $87,940,793,553      2.14%
# 11                    Hawaii (HI)   $15,336,370,543      0.37%
# 12                     Idaho (ID)   $17,000,463,101      0.41%
# 13                  Illinois (IL)  $109,447,513,878      2.67%
# ...

# %%
#k.to_csv('state_funding_2022.csv')

# %%
cv = pd.read_csv('NRI_Table_Counties.csv')
cv
# Out:
#       OID_  NRI_ID     STATE STATEABBRV  STATEFIPS      COUNTY COUNTYTYPE  \
# 0        1  C21115  Kentucky         KY         21     Johnson     County
# 1        2  C21117  Kentucky         KY         21      Kenton     County
# 2        3  C21119  Kentucky         KY         21       Knott     County
# 3        4  C21121  Kentucky         KY         21        Knox     County
# 4        5  C21123  Kentucky         KY         21       Larue     County
# ...    ...     ...       ...        ...        ...         ...        ...
# 3137  3138  C56037   Wyoming         WY         56  Sweetwater     County
# 3138  3139  C56039   Wyoming         WY         56       Teton     County
# 3139  3140  C56041   Wyoming         WY         56       Uinta     County
# 3140  3141  C56043   Wyoming         WY         56    Washakie     County
# 3141  3142  C56045   Wyoming         WY         56      Weston     County
#
#       COUNTYFIPS  STCOFIPS  POPULATION  ...     WNTW_EALB  WNTW_EALP  \
# ...

# %%
cv.columns = cv.columns.str.lower()

# %%
cv.head()
# Out:
#    oid_  nri_id     state stateabbrv  statefips   county countytype  \
# 0     1  C21115  Kentucky         KY         21  Johnson     County
# 1     2  C21117  Kentucky         KY         21   Kenton     County
# 2     3  C21119  Kentucky         KY         21    Knott     County
# 3     4  C21121  Kentucky         KY         21     Knox     County
# 4     5  C21123  Kentucky         KY         21    Larue     County
#
#    countyfips  stcofips  population  ...     wntw_ealb  wntw_ealp  \
# 0         115     21115       23356  ...    781.792240   0.006129
# 1         117     21117      159720  ...  18249.808380   0.006048
# 2         119     21119       16346  ...    249.454293   0.004021
# 3         121     21121       31883  ...  17055.601129   0.005838
# 4         123     21123       14193  ...   9662.424572   0.000390
#
#      wntw_ealpe   wntw_eala     wntw_ealt  wntw_eals            wntw_ealr  \
# 0  46577.171552    4.235939  47363.199731  19.448529  Relatively Moderate
# ...

# %%
cv.columns
# Out:
# Index(['oid_', 'nri_id', 'state', 'stateabbrv', 'statefips', 'county',
#        'countytype', 'countyfips', 'stcofips', 'population',
#        ...
#        'wntw_ealb', 'wntw_ealp', 'wntw_ealpe', 'wntw_eala', 'wntw_ealt',
#        'wntw_eals', 'wntw_ealr', 'wntw_risks', 'wntw_riskr', 'nri_ver'],
#       dtype='object', length=365)

# %%
cv.countytype.value_counts()
# Out:
# County              3007
# Parish                64
# City                  41
# Borough               13
# Census Area           10
# City and Borough       4
# Municipality           2
# Name: countytype, dtype: int64

# %%
cv[cv.countytype == 'Municipality']
# Out:
#       oid_  nri_id   state stateabbrv  statefips     county    countytype  \
# 1137  1138  C02020  Alaska         AK          2  Anchorage  Municipality
# 1158  1159  C02230  Alaska         AK          2    Skagway  Municipality
#
#       countyfips  stcofips  population  ...   wntw_ealb  wntw_ealp  \
# 1137          20      2020      291826  ...   79.864278   0.004287
# 1158         230      2230         968  ...  174.556305   0.000556
#
#         wntw_ealpe   wntw_eala     wntw_ealt  wntw_eals       wntw_ealr  \
# 1137  32579.126895  164.753096  32823.744268  17.210855  Relatively Low
# 1158   4225.957544    0.000000   4400.513849   8.808613        Very Low
#
#       wntw_risks wntw_riskr        nri_ver
# 1137    7.576194   Very Low  November 2021
# 1158    4.481600   Very Low  November 2021
#
# [2 rows x 365 columns]

# %%
cv[cv.state == 'Kentucky']#.county.value_counts()
# Out:
#       oid_  nri_id     state stateabbrv  statefips     county countytype  \
# 0        1  C21115  Kentucky         KY         21    Johnson     County
# 1        2  C21117  Kentucky         KY         21     Kenton     County
# 2        3  C21119  Kentucky         KY         21      Knott     County
# 3        4  C21121  Kentucky         KY         21       Knox     County
# 4        5  C21123  Kentucky         KY         21      Larue     County
# ...    ...     ...       ...        ...        ...        ...        ...
# 2364  2365  C21105  Kentucky         KY         21    Hickman     County
# 2365  2366  C21107  Kentucky         KY         21    Hopkins     County
# 2366  2367  C21109  Kentucky         KY         21    Jackson     County
# 2367  2368  C21111  Kentucky         KY         21  Jefferson     County
# 2368  2369  C21113  Kentucky         KY         21  Jessamine     County
#
#       countyfips  stcofips  population  ...     wntw_ealb  wntw_ealp  \
# ...

# %%
cv.population.sort_values()
# Out:
# 2673         82
# 1615         90
# 2657        286
# 2653        416
# 608         460
#          ...
# 1289    3095313
# 1170    3817117
# 2623    4092459
# 1677    5194675
# 1271    9818605
# Name: population, Length: 3142, dtype: int64

# %%
cv = cv[cv.countytype == 'County']
cv.head()
# Out:
#    oid_  nri_id     state stateabbrv  statefips   county countytype  \
# 0     1  C21115  Kentucky         KY         21  Johnson     County
# 1     2  C21117  Kentucky         KY         21   Kenton     County
# 2     3  C21119  Kentucky         KY         21    Knott     County
# 3     4  C21121  Kentucky         KY         21     Knox     County
# 4     5  C21123  Kentucky         KY         21    Larue     County
#
#    countyfips  stcofips  population  ...     wntw_ealb  wntw_ealp  \
# 0         115     21115       23356  ...    781.792240   0.006129
# 1         117     21117      159720  ...  18249.808380   0.006048
# 2         119     21119       16346  ...    249.454293   0.004021
# 3         121     21121       31883  ...  17055.601129   0.005838
# 4         123     21123       14193  ...   9662.424572   0.000390
#
#      wntw_ealpe   wntw_eala     wntw_ealt  wntw_eals            wntw_ealr  \
# 0  46577.171552    4.235939  47363.199731  19.448529  Relatively Moderate
# ...

# %%
cv[['risk_score','risk_ratng']].sort_values(by='risk_score')
# Out:
#       risk_score risk_ratng
# 2902    0.000000   Very Low
# 2673    0.004606   Very Low
# 1479    0.009269   Very Low
# 1329    0.341317   Very Low
# 1991    0.679850   Very Low
# ...          ...        ...
# 828    55.547136  Very High
# 1285   58.865953  Very High
# 1429   63.926384  Very High
# 2623   80.618536  Very High
# 1271  100.000000  Very High
#
# [3007 rows x 2 columns]

# %%
cv[['risk_score','risk_ratng']].sort_values(by='risk_score').risk_ratng.value_counts().index
# Out:
# Index(['Very Low', 'Relatively Low', 'Relatively Moderate', 'Relatively High',
#        'Very High'],
#       dtype='object')

# %%
for val in cv[['risk_score','risk_ratng']].sort_values(by='risk_score').risk_ratng.value_counts().index:
    print(val)
    print(f'''Range: {cv[['risk_score','risk_ratng']].sort_values(by='risk_score')[cv.risk_ratng == val].min()} to {cv[['risk_score','risk_ratng']].sort_values(by='risk_score')[cv.risk_ratng == val].max()}''')
    print(cv[['risk_score','risk_ratng']].sort_values(by='risk_score')[cv.risk_ratng == val].min())
    print(cv[['risk_score','risk_ratng']].sort_values(by='risk_score')[cv.risk_ratng == val].max())
    print('----')
# Out:
# Very Low
# Range: risk_score         0.0
# risk_ratng    Very Low
# dtype: object to risk_score    8.088062
# risk_ratng    Very Low
# dtype: object
# risk_score         0.0
# risk_ratng    Very Low
# dtype: object
# risk_score    8.088062
# risk_ratng    Very Low
# dtype: object
# ----
# Relatively Low
# Range: risk_score          8.095877
# risk_ratng    Relatively Low
# dtype: object to risk_score         13.381618
# risk_ratng    Relatively Low
# dtype: object
# risk_score          8.095877
# risk_ratng    Relatively Low
# dtype: object
# risk_score         13.381618
# risk_ratng    Relatively Low
# dtype: object
# ----
# Relatively Moderate
# Range: risk_score              13.438042
# risk_ratng    Relatively Moderate
# dtype: object to risk_score              22.750567
# risk_ratng    Relatively Moderate
# dtype: object
# risk_score              13.438042
# risk_ratng    Relatively Moderate
# dtype: object
# risk_score              22.750567
# risk_ratng    Relatively Moderate
# ...

# %%
cv[['risk_score','risk_ratng']].sort_values(by='risk_score')
# Out:
#       risk_score risk_ratng
# 2902    0.000000   Very Low
# 2673    0.004606   Very Low
# 1479    0.009269   Very Low
# 1329    0.341317   Very Low
# 1991    0.679850   Very Low
# ...          ...        ...
# 828    55.547136  Very High
# 1285   58.865953  Very High
# 1429   63.926384  Very High
# 2623   80.618536  Very High
# 1271  100.000000  Very High
#
# [3007 rows x 2 columns]

# %%
cv[['risk_score','risk_ratng']].sort_values(by='risk_score')[cv.risk_ratng == 'Very Low']
# Out:
# /var/folders/t2/c4rfp_5j33nfsbfkcj7scwjh0000gn/T/ipykernel_25001/3855379884.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cv[['risk_score','risk_ratng']].sort_values(by='risk_score')[cv.risk_ratng == 'Very Low']
#       risk_score risk_ratng
# 2902    0.000000   Very Low
# 2673    0.004606   Very Low
# 1479    0.009269   Very Low
# 1329    0.341317   Very Low
# 1991    0.679850   Very Low
# ...          ...        ...
# 32      8.085132   Very Low
# 131     8.087043   Very Low
# 2478    8.087114   Very Low
# 2066    8.087894   Very Low
# 308     8.088062   Very Low
#
# [1199 rows x 2 columns]

# %%
cv[['risk_score','risk_ratng']].sort_values(by='risk_score')[cv.risk_ratng == 'Very High'].max()
# Out:
# /var/folders/t2/c4rfp_5j33nfsbfkcj7scwjh0000gn/T/ipykernel_25001/947594866.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cv[['risk_score','risk_ratng']].sort_values(by='risk_score')[cv.risk_ratng == 'Very High'].max()
# risk_score        100.0
# risk_ratng    Very High
# dtype: object

# %%
pd.cut(cv., 3)

# %% [markdown]
# NRI_ver: Nov 2021
# Disasters: Drought,

# %%
i = cv.drop(columns={'oid_', 'stcofips', 'statefips', 'countytype', 'state', 'nri_id', 'nri_ver'}).iloc[:,:264]
i
# Out:
#      stateabbrv      county  countyfips  population    buildvalue   agrivalue  \
# 0            KY     Johnson         115       23356  1.924008e+09    706000.0
# 1            KY      Kenton         117      159720  1.877338e+10   5390000.0
# 2            KY       Knott         119       16346  1.170376e+09    408000.0
# 3            KY        Knox         121       31883  2.135773e+09   2534000.0
# 4            KY       Larue         123       14193  1.221343e+09  41112000.0
# ...         ...         ...         ...         ...           ...         ...
# 3137         WY  Sweetwater          37       43806  4.583896e+09  16454000.0
# 3138         WY       Teton          39       21294  3.476594e+09  17582000.0
# 3139         WY       Uinta          41       21118  2.018844e+09  26662000.0
# 3140         WY    Washakie          43        8533  8.867450e+08  43019000.0
# 3141         WY      Weston          45        7208  7.744440e+08  34274000.0
#
# ...

# %% [markdown]
# '_evnts', '_afreq', '_expb','_expp', '_exppe', '_expa', '_expt', '_hlrb', '_hlrp', '_hlra','swnd_hlrr', 'swnd_ealb', 'swnd_ealp', 'swnd_ealpe', 'swnd_eala',
#        'swnd_ealt', 'swnd_eals', 'swnd_ealr', 'swnd_risks', 'swnd_riskr'

# %%
ty = i.drop(columns={'rfld_evnts', 'rfld_afreq', 'rfld_expb','rfld_expp', 'rfld_exppe', 'rfld_expa', 'rfld_expt',
                'rfld_hlrb', 'rfld_hlrp', 'rfld_hlra', 'rfld_hlrr', 'rfld_ealb', 'rfld_ealp', 'rfld_ealpe',
                'rfld_eala', 'rfld_ealt', 'rfld_eals', 'rfld_ealr', 'rfld_risks', 'rfld_riskr', })
ty
# Out:
#      stateabbrv      county  countyfips  population    buildvalue   agrivalue  \
# 0            KY     Johnson         115       23356  1.924008e+09    706000.0
# 1            KY      Kenton         117      159720  1.877338e+10   5390000.0
# 2            KY       Knott         119       16346  1.170376e+09    408000.0
# 3            KY        Knox         121       31883  2.135773e+09   2534000.0
# 4            KY       Larue         123       14193  1.221343e+09  41112000.0
# ...         ...         ...         ...         ...           ...         ...
# 3137         WY  Sweetwater          37       43806  4.583896e+09  16454000.0
# 3138         WY       Teton          39       21294  3.476594e+09  17582000.0
# 3139         WY       Uinta          41       21118  2.018844e+09  26662000.0
# 3140         WY    Washakie          43        8533  8.867450e+08  43019000.0
# 3141         WY      Weston          45        7208  7.744440e+08  34274000.0
#
# ...

# %% [markdown]
# df = df[df.columns.drop(list(df.filter(regex='Test')))]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='lnds')))]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='istm')))]
ty.head()
# Out:
#   stateabbrv   county  countyfips  population    buildvalue   agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09    706000.0
# 1         KY   Kenton         117      159720  1.877338e+10   5390000.0
# 2         KY    Knott         119       16346  1.170376e+09    408000.0
# 3         KY     Knox         121       31883  2.135773e+09   2534000.0
# 4         KY    Larue         123       14193  1.221343e+09  41112000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...  swnd_hlrr  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...   Very Low
# 1  160.213975   10.449057  Relatively Low   61.489497  ...   Very Low
# 2  351.517978   10.068395  Relatively Low   58.465945  ...   Very Low
# 3  386.298435   11.858245  Relatively Low   71.928708  ...   Very Low
# 4  261.539564    4.610900        Very Low    8.434118  ...   Very Low
#
#        swnd_ealb swnd_ealp    swnd_ealpe    swnd_eala     swnd_ealt  \
# ...

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='hail')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...  swnd_hlrr  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...   Very Low
# 1  160.213975   10.449057  Relatively Low   61.489497  ...   Very Low
#
#        swnd_ealb swnd_ealp    swnd_ealpe  swnd_eala     swnd_ealt  swnd_eals  \
# 0   80154.579141  0.009813  7.458044e+04  68.990480  1.548040e+05  20.512333
# 1  787710.787042  0.142998  1.086788e+06   3.953417  1.874503e+06  47.103124
#
#          swnd_ealr  swnd_risks           swnd_riskr
# 0   Relatively Low   10.756017       Relatively Low
# 1  Relatively High   19.688303  Relatively Moderate
#
# [2 rows x 190 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='erqk')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...  swnd_hlrr  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...   Very Low
# 1  160.213975   10.449057  Relatively Low   61.489497  ...   Very Low
#
#        swnd_ealb swnd_ealp    swnd_ealpe  swnd_eala     swnd_ealt  swnd_eals  \
# 0   80154.579141  0.009813  7.458044e+04  68.990480  1.548040e+05  20.512333
# 1  787710.787042  0.142998  1.086788e+06   3.953417  1.874503e+06  47.103124
#
#          swnd_ealr  swnd_risks           swnd_riskr
# 0   Relatively Low   10.756017       Relatively Low
# 1  Relatively High   19.688303  Relatively Moderate
#
# [2 rows x 173 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='cwav')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...  swnd_hlrr  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...   Very Low
# 1  160.213975   10.449057  Relatively Low   61.489497  ...   Very Low
#
#        swnd_ealb swnd_ealp    swnd_ealpe  swnd_eala     swnd_ealt  swnd_eals  \
# 0   80154.579141  0.009813  7.458044e+04  68.990480  1.548040e+05  20.512333
# 1  787710.787042  0.142998  1.086788e+06   3.953417  1.874503e+06  47.103124
#
#          swnd_ealr  swnd_risks           swnd_riskr
# 0   Relatively Low   10.756017       Relatively Low
# 1  Relatively High   19.688303  Relatively Moderate
#
# [2 rows x 153 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='avln')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...  swnd_hlrr  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...   Very Low
# 1  160.213975   10.449057  Relatively Low   61.489497  ...   Very Low
#
#        swnd_ealb swnd_ealp    swnd_ealpe  swnd_eala     swnd_ealt  swnd_eals  \
# 0   80154.579141  0.009813  7.458044e+04  68.990480  1.548040e+05  20.512333
# 1  787710.787042  0.142998  1.086788e+06   3.953417  1.874503e+06  47.103124
#
#          swnd_ealr  swnd_risks           swnd_riskr
# 0   Relatively Low   10.756017       Relatively Low
# 1  Relatively High   19.688303  Relatively Moderate
#
# [2 rows x 119 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='hwav')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...  swnd_hlrr  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...   Very Low
# 1  160.213975   10.449057  Relatively Low   61.489497  ...   Very Low
#
#        swnd_ealb swnd_ealp    swnd_ealpe  swnd_eala     swnd_ealt  swnd_eals  \
# 0   80154.579141  0.009813  7.458044e+04  68.990480  1.548040e+05  20.512333
# 1  787710.787042  0.142998  1.086788e+06   3.953417  1.874503e+06  47.103124
#
#          swnd_ealr  swnd_risks           swnd_riskr
# 0   Relatively Low   10.756017       Relatively Low
# 1  Relatively High   19.688303  Relatively Moderate
#
# [2 rows x 99 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='sovi')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...  swnd_hlrr  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...   Very Low
# 1  160.213975   10.449057  Relatively Low   61.489497  ...   Very Low
#
#        swnd_ealb swnd_ealp    swnd_ealpe  swnd_eala     swnd_ealt  swnd_eals  \
# 0   80154.579141  0.009813  7.458044e+04  68.990480  1.548040e+05  20.512333
# 1  787710.787042  0.142998  1.086788e+06   3.953417  1.874503e+06  47.103124
#
#          swnd_ealr  swnd_risks           swnd_riskr
# 0   Relatively Low   10.756017       Relatively Low
# 1  Relatively High   19.688303  Relatively Moderate
#
# [2 rows x 94 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='ealr')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...     swnd_hlra  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...  2.823162e-05
# 1  160.213975   10.449057  Relatively Low   61.489497  ...  2.168773e-07
#
#    swnd_hlrr      swnd_ealb  swnd_ealp    swnd_ealpe  swnd_eala     swnd_ealt  \
# 0   Very Low   80154.579141   0.009813  7.458044e+04  68.990480  1.548040e+05
# 1   Very Low  787710.787042   0.142998  1.086788e+06   3.953417  1.874503e+06
#
#    swnd_eals  swnd_risks           swnd_riskr
# 0  20.512333   10.756017       Relatively Low
# 1  47.103124   19.688303  Relatively Moderate
#
# [2 rows x 90 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='riskr')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...     swnd_hlrp  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...  1.174652e-07
# 1  160.213975   10.449057  Relatively Low   61.489497  ...  2.708919e-07
#
#       swnd_hlra swnd_hlrr      swnd_ealb  swnd_ealp    swnd_ealpe  swnd_eala  \
# 0  2.823162e-05  Very Low   80154.579141   0.009813  7.458044e+04  68.990480
# 1  2.168773e-07  Very Low  787710.787042   0.142998  1.086788e+06   3.953417
#
#       swnd_ealt  swnd_eals  swnd_risks
# 0  1.548040e+05  20.512333   10.756017
# 1  1.874503e+06  47.103124   19.688303
#
# [2 rows x 86 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='expb')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...     swnd_hlrp  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...  1.174652e-07
# 1  160.213975   10.449057  Relatively Low   61.489497  ...  2.708919e-07
#
#       swnd_hlra swnd_hlrr      swnd_ealb  swnd_ealp    swnd_ealpe  swnd_eala  \
# 0  2.823162e-05  Very Low   80154.579141   0.009813  7.458044e+04  68.990480
# 1  2.168773e-07  Very Low  787710.787042   0.142998  1.086788e+06   3.953417
#
#       swnd_ealt  swnd_eals  swnd_risks
# 0  1.548040e+05  20.512333   10.756017
# 1  1.874503e+06  47.103124   19.688303
#
# [2 rows x 83 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='expp')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...     swnd_hlrp  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...  1.174652e-07
# 1  160.213975   10.449057  Relatively Low   61.489497  ...  2.708919e-07
#
#       swnd_hlra swnd_hlrr      swnd_ealb  swnd_ealp    swnd_ealpe  swnd_eala  \
# 0  2.823162e-05  Very Low   80154.579141   0.009813  7.458044e+04  68.990480
# 1  2.168773e-07  Very Low  787710.787042   0.142998  1.086788e+06   3.953417
#
#       swnd_ealt  swnd_eals  swnd_risks
# 0  1.548040e+05  20.512333   10.756017
# 1  1.874503e+06  47.103124   19.688303
#
# [2 rows x 77 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='expa')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...     swnd_hlrp  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...  1.174652e-07
# 1  160.213975   10.449057  Relatively Low   61.489497  ...  2.708919e-07
#
#       swnd_hlra swnd_hlrr      swnd_ealb  swnd_ealp    swnd_ealpe  swnd_eala  \
# 0  2.823162e-05  Very Low   80154.579141   0.009813  7.458044e+04  68.990480
# 1  2.168773e-07  Very Low  787710.787042   0.142998  1.086788e+06   3.953417
#
#       swnd_ealt  swnd_eals  swnd_risks
# 0  1.548040e+05  20.512333   10.756017
# 1  1.874503e+06  47.103124   19.688303
#
# [2 rows x 74 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='expt')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...     swnd_hlrp  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...  1.174652e-07
# 1  160.213975   10.449057  Relatively Low   61.489497  ...  2.708919e-07
#
#       swnd_hlra swnd_hlrr      swnd_ealb  swnd_ealp    swnd_ealpe  swnd_eala  \
# 0  2.823162e-05  Very Low   80154.579141   0.009813  7.458044e+04  68.990480
# 1  2.168773e-07  Very Low  787710.787042   0.142998  1.086788e+06   3.953417
#
#       swnd_ealt  swnd_eals  swnd_risks
# 0  1.548040e+05  20.512333   10.756017
# 1  1.874503e+06  47.103124   19.688303
#
# [2 rows x 70 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='eal')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...     ltng_hlrp  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...  4.117323e-09
# 1  160.213975   10.449057  Relatively Low   61.489497  ...  3.275580e-10
#
#    ltng_hlrr ltng_risks  swnd_evnts  swnd_afreq  swnd_hlrb     swnd_hlrp  \
# 0   Very Low   9.808591       112.0    3.498091   0.000011  1.174652e-07
# 1   Very Low   7.206740       107.0    3.335780   0.000013  2.708919e-07
#
#       swnd_hlra  swnd_hlrr swnd_risks
# 0  2.823162e-05   Very Low  10.756017
# 1  2.168773e-07   Very Low  19.688303
#
# [2 rows x 41 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='hlr')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...  drgt_risks  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...    1.851534
# 1  160.213975   10.449057  Relatively Low   61.489497  ...    2.014429
#
#    hrcn_evnts hrcn_afreq  hrcn_risks  ltng_evnts  ltng_afreq  ltng_risks  \
# 0         2.0   0.017975    1.668058      1274.0   57.907452    9.808591
# 1         1.0   0.006514    1.875497      1814.0   82.430625    7.206740
#
#    swnd_evnts  swnd_afreq  swnd_risks
# 0       112.0    3.498091   10.756017
# 1       107.0    3.335780   19.688303
#
# [2 rows x 28 columns]

# %% [markdown]
# ---

# %%
print(ty.columns.tolist())
# Out:
# ['stateabbrv', 'county', 'countyfips', 'population', 'buildvalue', 'agrivalue', 'area', 'risk_score', 'risk_ratng', 'risk_npctl', 'risk_spctl', 'resl_score', 'resl_ratng', 'resl_npctl', 'resl_spctl', 'resl_value', 'drgt_evnts', 'drgt_afreq', 'drgt_risks', 'hrcn_evnts', 'hrcn_afreq', 'hrcn_risks', 'ltng_evnts', 'ltng_afreq', 'ltng_risks', 'swnd_evnts', 'swnd_afreq', 'swnd_risks']

# %%
ty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3007 entries, 0 to 3141
# Data columns (total 29 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   stateabbrv  3007 non-null   object
#  1   county      3007 non-null   object
#  2   countyfips  3007 non-null   int64
#  3   population  3007 non-null   int64
#  4   buildvalue  3007 non-null   float64
#  5   agrivalue   3007 non-null   float64
#  6   area        3007 non-null   float64
#  7   risk_score  3007 non-null   float64
#  8   risk_ratng  3007 non-null   object
#  9   risk_npctl  3007 non-null   float64
#  10  risk_spctl  3007 non-null   float64
#  11  resl_score  3007 non-null   float64
#  12  resl_ratng  3007 non-null   object
#  13  resl_npctl  3007 non-null   float64
#  14  resl_spctl  3007 non-null   float64
#  15  resl_value  3007 non-null   float64
#  16  drgt_evnts  3007 non-null   float64
#  17  drgt_afreq  3007 non-null   float64
# ...

# %%
ls = ty[['ltng_risks','swnd_risks']]

# %%
ls.head()
# Out:
#    ltng_risks  swnd_risks
# 0    9.808591   10.756017
# 1    7.206740   19.688303
# 2   10.030535   12.431024
# 3   17.067191   17.589118
# 4    7.711309   11.899304

# %%
ls['diff'] = ls['ltng_risks'] - ls['swnd_risks']
ls
# Out:
# /var/folders/t2/c4rfp_5j33nfsbfkcj7scwjh0000gn/T/ipykernel_25001/524302949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ls['diff'] = ls['ltng_risks'] - ls['swnd_risks']
#       ltng_risks  swnd_risks       diff
# 0       9.808591   10.756017  -0.947426
# 1       7.206740   19.688303 -12.481563
# 2      10.030535   12.431024  -2.400489
# 3      17.067191   17.589118  -0.521928
# 4       7.711309   11.899304  -4.187994
# ...          ...         ...        ...
# 3137    4.114818    2.848189   1.266629
# 3138    9.277852    3.143585   6.134267
# 3139    6.221991    4.959357   1.262634
# 3140    8.747251    6.009518   2.737733
# 3141    4.973170    6.509292  -1.536123
#
# [3007 rows x 3 columns]

# %%
ls['diff'].max()
# Out:
# 79.78717774211049

# %%
ls['diff'].mean()
# Out:
# -0.08218399463631525

# %%
ls.describe()
# Out:
#         ltng_risks   swnd_risks         diff
# count  3002.000000  3007.000000  3002.000000
# mean     12.112289    12.182061    -0.082184
# std       8.024878     6.255249     7.798129
# min       0.000000     0.006388   -53.909568
# 25%       7.271299     8.090780    -4.325527
# 50%      10.510670    11.493431    -0.658615
# 75%      14.709127    15.305195     3.121064
# max     100.000000   100.000000    79.787178

# %%
ls[ls['diff'] == ls['diff'].max()]
# Out:
#       ltng_risks  swnd_risks       diff
# 1429       100.0   20.212822  79.787178

# %%
ty['storm_evnt'] = ty.ltng_evnts + ty.swnd_evnts

# %%
ty['storm_afreq'] = ty['storm_evnt']/27

# %%
(ty.ltng_risks + ty.swnd_risks)/2
# Out:
# 0       10.282304
# 1       13.447521
# 2       11.230780
# 3       17.328154
# 4        9.805307
#           ...
# 3137     3.481503
# 3138     6.210718
# 3139     5.590674
# 3140     7.378384
# 3141     5.741231
# Length: 3007, dtype: float64

# %%
ty['storm_risk'] = (ty.ltng_risks + ty.swnd_risks)/2

# %%
ty.head()
# Out:
#   stateabbrv   county  countyfips  population    buildvalue   agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09    706000.0
# 1         KY   Kenton         117      159720  1.877338e+10   5390000.0
# 2         KY    Knott         119       16346  1.170376e+09    408000.0
# 3         KY     Knox         121       31883  2.135773e+09   2534000.0
# 4         KY    Larue         123       14193  1.221343e+09  41112000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...  hrcn_risks  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...    1.668058
# 1  160.213975   10.449057  Relatively Low   61.489497  ...    1.875497
# 2  351.517978   10.068395  Relatively Low   58.465945  ...    1.129109
# 3  386.298435   11.858245  Relatively Low   71.928708  ...    1.962140
# 4  261.539564    4.610900        Very Low    8.434118  ...    2.473315
#
#    ltng_evnts ltng_afreq  ltng_risks  swnd_evnts  swnd_afreq  swnd_risks  \
# ...

# %%
ty.swnd_hlra.max()
# Out:
# 0.000846668406019

# %%
ty[ty.swnd_hlra == 0.000846668406019]
# Out:
#      stateabbrv county  countyfips  population    buildvalue    agrivalue  \
# 1310         CA   Yuba         115       72155  6.175685e+09  179111000.0
#
#             area  risk_score           risk_ratng  risk_npctl  ...  \
# 1310  631.839241   22.428967  Relatively Moderate    95.13049  ...
#
#          swnd_hlrp  swnd_hlra swnd_hlrr    swnd_ealb  swnd_ealp   swnd_ealpe  \
# 1310  2.297239e-07   0.000847  Very Low  2850.976358   0.000531  4034.947716
#
#         swnd_eala     swnd_ealt  swnd_eals  swnd_risks
# 1310  4745.080892  11631.004966   8.655525    4.934293
#
# [1 rows x 86 columns]

# %%
ty[ty.swnd_hlrr == 'Very High'].head()
# Out:
#     stateabbrv   county  countyfips  population   buildvalue    agrivalue  \
# 621         NE     Clay          35        6542  805528000.0  356051000.0
# 636         NE   Furnas          65        4959  653998000.0  240389000.0
# 640         NE   Gosper          73        2044  271869000.0  105730000.0
# 641         NE  Greeley          77        2538  329752000.0  193340000.0
# 645         NE   Harlan          83        3423  520519000.0  160275000.0
#
#            area  risk_score           risk_ratng  risk_npctl  ...  \
# 621  572.289227   11.984724       Relatively Low   72.533418  ...
# 636  719.131310   17.893252  Relatively Moderate   91.152132  ...
# 640  458.154903   11.421448       Relatively Low   69.000637  ...
# 641  569.810956   10.256760       Relatively Low   59.993635  ...
# 645  553.466132   12.443544       Relatively Low   74.633991  ...
#
#         swnd_hlrp  swnd_hlra  swnd_hlrr      swnd_ealb  swnd_ealp  \
# ...

# %%
ty['swnd_evnts']
# Out:
# 0       112.0
# 1       107.0
# 2       147.0
# 3       185.0
# 4       229.0
#         ...
# 3137      6.0
# 3138      7.0
# 3139     10.0
# 3140     11.0
# 3141     51.0
# Name: swnd_evnts, Length: 3007, dtype: float64

# %%
ty.drop(columns={'countyfips'})
# Out:
#      stateabbrv      county  population    buildvalue   agrivalue  \
# 0            KY     Johnson       23356  1.924008e+09    706000.0
# 1            KY      Kenton      159720  1.877338e+10   5390000.0
# 2            KY       Knott       16346  1.170376e+09    408000.0
# 3            KY        Knox       31883  2.135773e+09   2534000.0
# 4            KY       Larue       14193  1.221343e+09  41112000.0
# ...         ...         ...         ...           ...         ...
# 3137         WY  Sweetwater       43806  4.583896e+09  16454000.0
# 3138         WY       Teton       21294  3.476594e+09  17582000.0
# 3139         WY       Uinta       21118  2.018844e+09  26662000.0
# 3140         WY    Washakie        8533  8.867450e+08  43019000.0
# 3141         WY      Weston        7208  7.744440e+08  34274000.0
#
#               area  risk_score      risk_ratng  risk_npctl  risk_spctl  ...  \
# 0       261.958144    9.281419  Relatively Low   51.495863   70.000000  ...
# ...

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='ltng')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...  drgt_risks  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...    1.851534
# 1  160.213975   10.449057  Relatively Low   61.489497  ...    2.014429
#
#    hrcn_evnts hrcn_afreq  hrcn_risks  swnd_evnts  swnd_afreq  swnd_risks  \
# 0         2.0   0.017975    1.668058       112.0    3.498091   10.756017
# 1         1.0   0.006514    1.875497       107.0    3.335780   19.688303
#
#    storm_evnt  storm_afreq  storm_risk
# 0      1386.0    51.333333   10.282304
# 1      1921.0    71.148148   13.447521
#
# [2 rows x 28 columns]

# %%
ty = ty[ty.columns.drop(list(ty.filter(regex='swnd')))]
ty.head(2)
# Out:
#   stateabbrv   county  countyfips  population    buildvalue  agrivalue  \
# 0         KY  Johnson         115       23356  1.924008e+09   706000.0
# 1         KY   Kenton         117      159720  1.877338e+10  5390000.0
#
#          area  risk_score      risk_ratng  risk_npctl  ...  resl_value  \
# 0  261.958144    9.281419  Relatively Low   51.495863  ...     2.55643
# 1  160.213975   10.449057  Relatively Low   61.489497  ...     2.84015
#
#    drgt_evnts drgt_afreq  drgt_risks  hrcn_evnts  hrcn_afreq  hrcn_risks  \
# 0        77.0   4.277778    1.851534         2.0    0.017975    1.668058
# 1        56.0   3.111111    2.014429         1.0    0.006514    1.875497
#
#    storm_evnt  storm_afreq  storm_risk
# 0      1386.0    51.333333   10.282304
# 1      1921.0    71.148148   13.447521
#
# [2 rows x 25 columns]

# %%
ty.drop(columns={'countyfips'}, inplace=True)

# %%
ty
# Out:
#      stateabbrv      county  population    buildvalue   agrivalue  \
# 0            KY     Johnson       23356  1.924008e+09    706000.0
# 1            KY      Kenton      159720  1.877338e+10   5390000.0
# 2            KY       Knott       16346  1.170376e+09    408000.0
# 3            KY        Knox       31883  2.135773e+09   2534000.0
# 4            KY       Larue       14193  1.221343e+09  41112000.0
# ...         ...         ...         ...           ...         ...
# 3137         WY  Sweetwater       43806  4.583896e+09  16454000.0
# 3138         WY       Teton       21294  3.476594e+09  17582000.0
# 3139         WY       Uinta       21118  2.018844e+09  26662000.0
# 3140         WY    Washakie        8533  8.867450e+08  43019000.0
# 3141         WY      Weston        7208  7.744440e+08  34274000.0
#
#               area  risk_score      risk_ratng  risk_npctl  risk_spctl  ...  \
# 0       261.958144    9.281419  Relatively Low   51.495863   70.000000  ...
# ...

# %%
ty.isnull().sum()
# Out:
# stateabbrv       0
# county           0
# population       0
# buildvalue       0
# agrivalue        0
# area             0
# risk_score       0
# risk_ratng       0
# risk_npctl       0
# risk_spctl       0
# resl_score       0
# resl_ratng       0
# resl_npctl       0
# resl_spctl       0
# resl_value       0
# drgt_evnts       0
# drgt_afreq       0
# drgt_risks       0
# hrcn_evnts     883
# hrcn_afreq     883
# hrcn_risks     883
# storm_evnt       5
# storm_afreq      5
# storm_risk       5
# dtype: int64

# %%
ty[ty.hrcn_evnts.isnull()].stateabbrv.value_counts()
# Out:
# NE    93
# KS    86
# MN    86
# SD    66
# CO    64
# MT    56
# CA    55
# ND    53
# ID    44
# WA    39
# WI    38
# OR    36
# IA    29
# UT    29
# WY    23
# NM    22
# NV    16
# MO    16
# TX    13
# MI    13
# AZ     4
# OK     2
# Name: stateabbrv, dtype: int64

# %%
ty[ty.storm_evnt.isnull()]
# Out:
#      stateabbrv    county  population    buildvalue    agrivalue         area  \
# 1613         HI    Hawaii      185079  2.086041e+10  269188000.0  4028.448445
# 1614         HI  Honolulu      953207  1.020610e+11  151384000.0   600.612964
# 1615         HI   Kalawao          90  2.114200e+07          0.0    11.991403
# 1616         HI     Kauai       67091  8.264594e+09   61025000.0   619.883803
# 1617         HI      Maui      154834  1.958654e+10   82206000.0  1161.529513
#
#       risk_score           risk_ratng  risk_npctl  risk_spctl  ...  \
# 1613   35.833188      Relatively High   98.790579       100.0  ...
# 1614   23.021851      Relatively High   95.353278        80.0  ...
# 1615    1.636476             Very Low    0.827498        20.0  ...
# 1616   11.677485       Relatively Low   70.655633        40.0  ...
# 1617   17.889600  Relatively Moderate   91.120306        60.0  ...
#
#       resl_value drgt_evnts  drgt_afreq  drgt_risks  hrcn_evnts  hrcn_afreq  \
# ...

# %%
nb = ty

# %%
imputer = SimpleImputer(missing_values = None, strategy='constant')

# %%
#imputer = imputer.fit(ty[['hrcn_evnts', 'hrcn_afreq', 'hrcn_risks']])

# %%
ty.hrcn_evnts.fillna(0, inplace=True)

# %%
ty.hrcn_afreq.fillna(0, inplace=True)

# %%
ty.hrcn_risks.fillna(0, inplace=True)

# %%
ty.storm_afreq.fillna(25, inplace=True)

# %%
ty.isnull().sum()
# Out:
# stateabbrv     0
# county         0
# population     0
# buildvalue     0
# agrivalue      0
# area           0
# risk_score     0
# risk_ratng     0
# risk_npctl     0
# risk_spctl     0
# resl_score     0
# resl_ratng     0
# resl_npctl     0
# resl_spctl     0
# resl_value     0
# drgt_evnts     0
# drgt_afreq     0
# drgt_risks     0
# hrcn_evnts     0
# hrcn_afreq     0
# hrcn_risks     0
# storm_evnt     5
# storm_afreq    0
# storm_risk     5
# dtype: int64

# %%
25*27
# Out:
# 675

# %%
ty.storm_evnt.fillna(675, inplace=True)

# %%
ty
# Out:
#      stateabbrv      county  population    buildvalue   agrivalue  \
# 0            KY     Johnson       23356  1.924008e+09    706000.0
# 1            KY      Kenton      159720  1.877338e+10   5390000.0
# 2            KY       Knott       16346  1.170376e+09    408000.0
# 3            KY        Knox       31883  2.135773e+09   2534000.0
# 4            KY       Larue       14193  1.221343e+09  41112000.0
# ...         ...         ...         ...           ...         ...
# 3137         WY  Sweetwater       43806  4.583896e+09  16454000.0
# 3138         WY       Teton       21294  3.476594e+09  17582000.0
# 3139         WY       Uinta       21118  2.018844e+09  26662000.0
# 3140         WY    Washakie        8533  8.867450e+08  43019000.0
# 3141         WY      Weston        7208  7.744440e+08  34274000.0
#
#               area  risk_score      risk_ratng  risk_npctl  risk_spctl  ...  \
# 0       261.958144    9.281419  Relatively Low   51.495863   70.000000  ...
# ...

# %%
ty[ty.stateabbrv == 'FL'].storm_risk.mean()
# Out:
# 21.95716265995875

# %%
ty.storm_risk.fillna(21.95, inplace=True)

# %%
ty.isnull().sum()
# Out:
# stateabbrv     0
# county         0
# population     0
# buildvalue     0
# agrivalue      0
# area           0
# risk_score     0
# risk_ratng     0
# risk_npctl     0
# risk_spctl     0
# resl_score     0
# resl_ratng     0
# resl_npctl     0
# resl_spctl     0
# resl_value     0
# drgt_evnts     0
# drgt_afreq     0
# drgt_risks     0
# hrcn_evnts     0
# hrcn_afreq     0
# hrcn_risks     0
# storm_evnt     0
# storm_afreq    0
# storm_risk     0
# dtype: int64

# %%
ty.to_csv('county_risk.csv')

# %%
ty.head()
# Out:
#   stateabbrv   county  population    buildvalue   agrivalue        area  \
# 0         KY  Johnson       23356  1.924008e+09    706000.0  261.958144
# 1         KY   Kenton      159720  1.877338e+10   5390000.0  160.213975
# 2         KY    Knott       16346  1.170376e+09    408000.0  351.517978
# 3         KY     Knox       31883  2.135773e+09   2534000.0  386.298435
# 4         KY    Larue       14193  1.221343e+09  41112000.0  261.539564
#
#    risk_score      risk_ratng  risk_npctl  risk_spctl  ...  resl_value  \
# 0    9.281419  Relatively Low   51.495863   70.000000  ...     2.55643
# 1   10.449057  Relatively Low   61.489497   79.166667  ...     2.84015
# 2   10.068395  Relatively Low   58.465945   76.666667  ...     2.42617
# 3   11.858245  Relatively Low   71.928708   85.833333  ...     2.54769
# 4    4.610900        Very Low    8.434118    4.166667  ...     2.77579
#
#   drgt_evnts  drgt_afreq  drgt_risks  hrcn_evnts  hrcn_afreq  hrcn_risks  \
# ...

# %%
ty = ty.rename(columns={'stateabbrv':'state', 'storm_evnt':'storm_evnts', 'storm_risk': 'storm_risks', 'risk_ratng':'risk_rating'})

# %%
ty.to_csv('county_risk.csv')

# %%
ty
# Out:
#      state      county  population    buildvalue   agrivalue          area  \
# 0       KY     Johnson       23356  1.924008e+09    706000.0    261.958144
# 1       KY      Kenton      159720  1.877338e+10   5390000.0    160.213975
# 2       KY       Knott       16346  1.170376e+09    408000.0    351.517978
# 3       KY        Knox       31883  2.135773e+09   2534000.0    386.298435
# 4       KY       Larue       14193  1.221343e+09  41112000.0    261.539564
# ...    ...         ...         ...           ...         ...           ...
# 3137    WY  Sweetwater       43806  4.583896e+09  16454000.0  10426.919825
# 3138    WY       Teton       21294  3.476594e+09  17582000.0   3996.855337
# 3139    WY       Uinta       21118  2.018844e+09  26662000.0   2081.651840
# 3140    WY    Washakie        8533  8.867450e+08  43019000.0   2238.665800
# 3141    WY      Weston        7208  7.744440e+08  34274000.0   2398.003888
#
# ...
